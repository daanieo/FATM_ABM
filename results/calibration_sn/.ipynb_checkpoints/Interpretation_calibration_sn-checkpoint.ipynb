# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.style.use("seaborn-whitegrid")

# %%
# Calibration SN

# %%
data = pd.read_feather("calibration_sn")
input_vars = pd.read_csv("input_parameters.csv")
os = pd.read_csv("output_names.csv")

# %%
input_vars
# Out:
#     Unnamed: 0  capacity_policy  minfood_access_policy  ration_size_policy  \
# 0            0              0.0                    0.0                30.0
# 1            1              0.0                    0.0                30.0
# 2            2              0.0                    0.0                30.0
# 3            3              0.0                    0.0                30.0
# 4            4              0.0                    0.0                30.0
# 5            5              0.0                    0.0                30.0
# 6            6              0.0                    0.0                30.0
# 7            7              0.0                    0.0                30.0
# 8            8              0.0                    0.0                30.0
# 9            9              0.0                    0.0                30.0
# 10          10              0.0                    0.0                30.0
# 11          11              0.0                    0.0                30.0
# 12          12              0.0                    0.0                30.0
# 13          13              0.0                    0.0                30.0
# 14          14              0.0                    0.0                30.0
# 15          15              0.0                    0.0                30.0
# 16          16              0.0                    0.0                30.0
# 17          17              0.0                    0.0                30.0
# 18          18              0.0                    0.0                30.0
# 19          19              0.0                    0.0                30.0
# 20          20              0.0                    0.0                30.0
# 21          21              0.0                    0.0                30.0
# 22          22              0.0                    0.0                30.0
# 23          23              0.0                    0.0                30.0
# 24          24              0.0                    0.0                30.0
# 25          25              0.0                    0.0                30.0
# 26          26              0.0                    0.0                30.0
# 27          27              0.0                    0.0                30.0
# 28          28              0.0                    0.0                30.0
# 29          29              0.0                    0.0                30.0
#
#     day_access_policy  rerouting_policy  alpha  beta  gamma  epsilon  \
# 0                 0.0               0.0    1.0   1.0    3.0      0.1
# 1                 0.0               0.0    1.0   1.0    3.0      0.1
# 2                 0.0               0.0    1.0   1.0    3.0      0.1
# 3                 0.0               0.0    1.0   1.0    3.0      0.1
# 4                 0.0               0.0    1.0   1.0    3.0      0.1
# 5                 0.0               0.0    1.0   1.0    3.0      1.0
# 6                 0.0               0.0    1.0   1.0    3.0      1.0
# 7                 0.0               0.0    1.0   1.0    3.0      1.0
# 8                 0.0               0.0    1.0   1.0    3.0      1.0
# 9                 0.0               0.0    1.0   1.0    3.0      1.0
# 10                0.0               0.0    1.0   1.0    7.0      0.1
# 11                0.0               0.0    1.0   1.0    7.0      0.1
# 12                0.0               0.0    1.0   1.0    7.0      0.1
# 13                0.0               0.0    1.0   1.0    7.0      0.1
# 14                0.0               0.0    1.0   1.0    7.0      0.1
# 15                0.0               0.0    1.0   1.0    7.0      1.0
# 16                0.0               0.0    1.0   1.0    7.0      1.0
# 17                0.0               0.0    1.0   1.0    7.0      1.0
# 18                0.0               0.0    1.0   1.0    7.0      1.0
# 19                0.0               0.0    1.0   1.0    7.0      1.0
# 20                0.0               0.0    1.0   1.0   14.0      0.1
# 21                0.0               0.0    1.0   1.0   14.0      0.1
# 22                0.0               0.0    1.0   1.0   14.0      0.1
# 23                0.0               0.0    1.0   1.0   14.0      0.1
# 24                0.0               0.0    1.0   1.0   14.0      0.1
# 25                0.0               0.0    1.0   1.0   14.0      1.0
# 26                0.0               0.0    1.0   1.0   14.0      1.0
# 27                0.0               0.0    1.0   1.0   14.0      1.0
# 28                0.0               0.0    1.0   1.0   14.0      1.0
# 29                0.0               0.0    1.0   1.0   14.0      1.0
#
#     parallel_served_full  avg_interactions
# 0                    7.8               0.0
# 1                    7.8               5.0
# 2                    7.8              10.0
# 3                    7.8              20.0
# 4                    7.8              25.0
# 5                    7.8               0.0
# 6                    7.8               5.0
# 7                    7.8              10.0
# 8                    7.8              20.0
# 9                    7.8              25.0
# 10                   7.8               0.0
# 11                   7.8               5.0
# 12                   7.8              10.0
# 13                   7.8              20.0
# 14                   7.8              25.0
# 15                   7.8               0.0
# 16                   7.8               5.0
# 17                   7.8              10.0
# 18                   7.8              20.0
# 19                   7.8              25.0
# 20                   7.8               0.0
# 21                   7.8               5.0
# 22                   7.8              10.0
# 23                   7.8              20.0
# 24                   7.8              25.0
# 25                   7.8               0.0
# 26                   7.8               5.0
# 27                   7.8              10.0
# 28                   7.8              20.0
# 29                   7.8              25.0

# %%
def normalise(arr):
    arrmax = np.max(arr)
    arrmin = np.min(arr)
    
    arrnorm = (arr - arrmin) / (arrmax - arrmin)
    
    return arrnorm

# %%
# dict to store relevant indices

# x vector to plot            
x = np.linspace(0,4319,4320) 
colors = ['blue', 'red', 'green','yellow','purple']

input_vars_filtered = input_vars#[input_vars.gamma==3]
# # plot batch per color
# for i in [6.0,6.4,6.8,7.2,7.6,8.0,8.4,8.8,9.2,9.6,10,10.4,10.8,11.2,11.4,11.8]:  

#     for j in input_vars_filtered[input_vars_filtered.parallel_served_full==i].index:
#         plt.plot( x, data.o1[data.o0==j])#,color=colors[i-6], alpha=.75)
gammas = [3,7,14]
for i in range(3):  
    g = gammas[i]
    for j in input_vars_filtered[input_vars_filtered.gamma==g].index:
        plt.plot( x, data.o1[data.o0==j],color=colors[i], alpha=.75)

            
# graph layout
# plt.title("")
plt.ylabel("Cummulative unsatisfied consumption (kg)")
plt.xlabel("Tick (10 min)")
plt.xlim([0,4320])

from matplotlib.lines import Line2D

colors = ['blue', 'red', 'green','yellow']
lines = [Line2D([0], [0], color=c, linewidth=2, linestyle='-') for c in colors]
labels = ['γ = 3', 'γ = 4', 'γ = 5']
plt.legend(lines, labels)

# plt.ylim([-100,7500]);
# plt.savefig("/home/daan/Desktop/unsatisfied_consumption.png")

# %%
# dict to store relevant indices

# x vector to plot            
x = np.linspace(0,4319,4320) 
colors = ['blue', 'red', 'green','yellow','purple','black']

input_vars_filtered = input_vars[input_vars.gamma==3]
input_vars_filtered = input_vars_filtered[input_vars_filtered.epsilon==0.1]
# # plot batch per color
# for i in [6.0,6.4,6.8,7.2,7.6,8.0,8.4,8.8,9.2,9.6,10,10.4,10.8,11.2,11.4,11.8]:  

#     for j in input_vars_filtered[input_vars_filtered.parallel_served_full==i].index:
#         plt.plot( x, data.o1[data.o0==j])#,color=colors[i-6], alpha=.75)
gammas = [0,5,10,15,20,25]
for i in range(6):  
    g = gammas[i]
    for j in input_vars_filtered[input_vars_filtered.avg_interactions==g].index:
        plt.plot( x, data.o1[data.o0==j],color=colors[i], alpha=.75)

            
# graph layout
# plt.title("")
plt.ylabel("Cummulative unsatisfied consumption (kg)")
plt.xlabel("Tick (10 min)")
plt.xlim([0,4320])

from matplotlib.lines import Line2D

colors = ['blue', 'red', 'green','yellow','purple','black']
lines = [Line2D([0], [0], color=c, linewidth=2, linestyle='-') for c in colors]
labels = ['n = 0', 'n = 5','n = 10','n = 15','n = 20','n = 25']
plt.legend(lines, labels)

# %%
# dict to store relevant indices

# x vector to plot            
x = np.linspace(0,4319,4320) 
colors = ['blue', 'red', 'green','yellow','purple','black']


input_vars_filtered = input_vars[input_vars.epsilon==0.1]
cd = {}
labels = list()
gammas = [3,7,14]
for g in range(len(gammas)):
    cd[gammas[g]]=colors[g]
    labels.append('γ = %s'%gammas[g])

# plot batch per color
for i in [0,5,10,15,20,25]:    

    for j in input_vars_filtered[input_vars_filtered.avg_interactions==i].index:
        
        plt.plot( i, data.o1[data.o0==j].iloc[-1],marker='o',color=cd[input_vars_filtered[input_vars_filtered.avg_interactions==i].gamma[j]], alpha=.75)
            
# graph layout
# plt.title("")
plt.ylabel("Cumulative unsatisfied consumption (kg)")
plt.xlabel("Average number of people served per 10 min")
# plt.xlim([0,4320])

from matplotlib.lines import Line2D
lines = [Line2D([0], [0], color=c, linewidth=2, linestyle='-') for c in colors]
plt.legend(lines, labels)
plt.ylim([0,40000]);
# plt.savefig("/home/daan/Desktop/unsatisfied_consumption.png")

# %%
from matplotlib.lines import Line2D

# x vector to plot            
x = np.linspace(0,4319,4320) 
colors = ['blue', 'green']
labels = ['γ = 3','γ = 7']

fig,ax = plt.subplots(1,2,figsize=(20,5),sharey=True)

input_vars_filtered = input_vars[input_vars.epsilon==0.1]

# plot batch per color
for i in [0,5,10,15,20,25]:    

    for j in input_vars_filtered[input_vars_filtered.avg_interactions==i].index:
        
        if input_vars_filtered.gamma[j]==3:
            ax[0].plot( i, data.o1[data.o0==j].iloc[-1],marker='o',color='blue',markersize=12.5 ,alpha=.75)
        elif input_vars_filtered.gamma[j]==7:
            ax[1].plot( i, data.o1[data.o0==j].iloc[-1],marker='o',color='green',markersize=12.5, alpha=.75)

            
lines = [Line2D([0], [0], color=c, linewidth=10,marker='o' ,linestyle='None') for c in colors]
        
for a in ax:
    a.set_xlim([-0.5,25.5])
    a.set_ylim([0,40000])
    
    a.set_xlabel("Average number of people served per 10 min")
    a.legend(lines, labels)
    a.legend(lines,labels)
ax[0].set_ylabel("Cumulative unsatisfied consumption (kg)\nat end of day 30");


plt.savefig("/home/daan/Desktop/calibration_sn.png")
