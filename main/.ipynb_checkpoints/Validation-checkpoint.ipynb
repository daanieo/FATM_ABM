# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import networkx

# %%
# Create a fully connected network

nb_households = 20

sn_matrix = np.zeros([nb_households,nb_households])

network = networkx.Graph()


for i in range(nb_households):
    network.add_node(i)
    
    for j in range(i):

        network.add_edge(i,j)

        sn_matrix[i][j] = 1
        sn_matrix[j][i] = 1
                   

networkx.draw_shell(network, with_labels=True, font_weight='bold')

sn_matrix_df = pd.DataFrame(sn_matrix)
sn_matrix_df.to_csv("fully_matrix.csv",index=False,header=False)

# %%
# Create a sparsely connected network

nb_households = 20
avg_sn_size = 3

sn_matrix = np.zeros([nb_households,nb_households])

network = networkx.Graph()


for i in range(nb_households):
    network.add_node(i)
    
    for j in range(i):
        
        if random.uniform(0,1) < avg_sn_size/nb_households:
            
            network.add_edge(i,j)
            
            sn_matrix[i][j] = 1
            sn_matrix[j][i] = 1
                   

networkx.draw_shell(network, with_labels=True, font_weight='bold')

sn_matrix_df = pd.DataFrame(sn_matrix)
sn_matrix_df.to_csv("sparsely_matrix.csv",index=False,header=False)

# %%
nb_runs = 100
nb_ticks = 100

nb_households = 5


runs = {}

for i in range(nb_runs):
    tmp= pd.read_csv("results/result%s.csv"%i,skiprows=1,header=None,sep="],",engine='python')    
    
    
    
    households = {}
    for j in range(nb_households):
        cleanlist = list()
        for k in tmp[j][0][1:-1].split(','):
            
            cleanlist.append(float(k))
            
        households[j] = cleanlist
    runs[i] = households
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-a500094fb68c> in <module>
#       8
#       9 for i in range(nb_runs):
# ---> 10     tmp= pd.read_csv("results/result%s.csv"%i,skiprows=1,header=None,sep="],",engine='python')
#      11
#      12
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1187                     'are "c", "python", or "python-fwf")'
#    1188                 )
# -> 1189             self._engine = klass(self.f, **self.options)
#    1190
#    1191     def _failover_to_python(self):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, **kwds)
#    2380         self._comment_lines = []
#    2381
# -> 2382         f, handles = get_handle(
#    2383             f,
#    2384             "r",
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     494         elif is_text:
#     495             # No explicit encoding
# --> 496             f = open(path_or_buf, mode, errors="replace", newline="")
#     497         else:
#     498             # Binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: 'results/result0.csv'

# %%
for i in runs:
    for j in runs[i]:
        plt.plot(runs[i][0][1:])

# %%
for j in runs[0]:
    plt.plot(runs[j][0][1:])

# %%
for j in runs[1]:
    plt.plot(runs[j][0][1:])

# %%
nb_runs = 100
nb_ticks = 100

nb_households = 5


runs = {}

for i in range(nb_runs):
    tmp= pd.read_csv("results/avg_es%s.csv"%i,skiprows=1,header=None,sep="],",engine='python')    
   

    cleanlist = list()
    for k in tmp[0][0][1:-1].split(','):

        cleanlist.append(float(k))

    runs[i] = cleanlist

# %%
for r in runs:
    plt.plot(runs[r])

# %%
runs = {}
betas = list()
for b in range(11):
    betas.append(b/10.)

for a in range(nb_runs):
    
    
    beta_results = {}   
    for b in betas:
        tmp= pd.read_csv("results/avg_es%sbeta%s.csv"%(a,b),skiprows=1,header=None,sep="],",engine='python') 
        
     
        cleanlist = list()
        for k in tmp[0][0][1:-1].split(','):

            cleanlist.append(float(k))
        
        beta_results[b] = cleanlist
    runs[a] = beta_results

# %%
for r in runs:
    for b in betas:
        plt.plot(runs[r][b])
        plt.plot(runs[r][b])

# %%
plt.plot(runs[0][0.0])

# %%
plt.plot(runs[0][1.0])
